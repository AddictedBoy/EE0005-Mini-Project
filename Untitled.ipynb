# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()
#import math

# %%
winedata = pd.read_csv('wine.csv')
winedata.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
winedata.info()
winedata.isnull().any() 
winedata.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# ...

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(12, 2, figsize=(25, 45))
colors = ["r", "g", "b", "m", "c", "r", "g", "b", "m", "c","r", "g"]

count = 0
for var in winedata:
    sb.boxplot(data=winedata[var], orient = "h", color = colors[count], ax = axes[count,0])
    sb.histplot(data=winedata[var], color = colors[count], ax = axes[count,1])
    count += 1

# %%
# Import Decision Tree Classifier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier
# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 2)

winecat = pd.DataFrame(winedata[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH','sulphates', 'alcohol', 'quality']])

# Split the dataset into Train and Test       
winecattrain = pd.DataFrame(winecat[:1200])
winecattest  = pd.DataFrame(winecat[-400:])
# Check the sample sizes
print("Train Set :", winecattrain.shape)
print("Test Set  :", winecattest.shape)
# Out:
# Train Set : (1200, 12)
# Test Set  : (400, 12)

# %%
# Extract the two variables X_train and y_train
y_train = pd.DataFrame(winecattrain['fixed acidity'])
X_train = pd.DataFrame(winecattrain['quality'])

# %%
res = list(map(math.ceil, y_train))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-73ccb39931e2> in <module>
# ----> 1 res = list(map(math.ceil, y_train))
#
# TypeError: must be real number, not str

# %%
# Train the Decision Tree Classifier model
dectree.fit(res1, res)

from sklearn.tree import plot_tree
fig, ax = plt.subplots(figsize=(12, 12))
out = plot_tree(dectree, 
          feature_names = res1.columns,
          class_names = [int(x) for x in dectree.classes_],
          filled=True)

for o in out:
    arrow = o.arrow_patch
    if arrow is not None:
        arrow.set_edgecolor('black')
        arrow.set_linewidth(3)
        
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-df711dfceefb> in <module>
#       1 # Train the Decision Tree Classifier model
# ----> 2 dectree.fit(res1, res)
#       3
#       4 from sklearn.tree import plot_tree
#       5 fig, ax = plt.subplots(figsize=(12, 12))
#
# NameError: name 'res1' is not defined
